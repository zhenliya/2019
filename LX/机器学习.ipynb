# %%
import numpy as np
import pandas as pd

# %%
label=[1,0,1,0,1]
data = pd.Series(data=label,index=['a','b','c','d','e'],dtype=int,name="label")
print (data)
# Out:
# a    1
# b    0
# c    1
# d    0
# e    1
# Name: label, dtype: int32

# %%
data['a']
data[['a','b']]
# Out:
# a    1
# b    0
# Name: label, dtype: int32

# %%
frame = pd.DataFrame({'name':['Time','Jack','Lily'],'Age':[20,30,12],"weight":[56.7,64.0,50.0]})

# %%
frame1 = pd.DataFrame(frame,columns=["name","Age"])

# %%
frame1["friends_num"]=[10,12,14]

# %%
frame1
# Out:
#    name  Age  friends_num
# 0  Time   20           10
# 1  Jack   30           12
# 2  Lily   12           14

# %%
frame2 = frame1.drop(["name","Age"],axis=1)

# %%
frame2
# Out:
#    friends_num
# 0           10
# 1           12
# 2           14

# %%
frame1[frame1["friends_num"]>10]
# Out:
#    name  Age  friends_num
# 1  Jack   30           12
# 2  Lily   12           14

# %%
 frame1["Age_group"] = frame1["Age"].apply(lambda x: 0 if x < 20 else 1)

# %%
frame1
# Out:
#    name  Age  friends_num  Age_group
# 0  Time   20           10          1
# 1  Jack   30           12          1
# 2  Lily   12           14          0

# %%
frame1.describe()
# Out:
#              Age  friends_num  Age_group
# count   3.000000          3.0   3.000000
# mean   20.666667         12.0   0.666667
# std     9.018500          2.0   0.577350
# min    12.000000         10.0   0.000000
# 25%    16.000000         11.0   0.500000
# 50%    20.000000         12.0   1.000000
# 75%    25.000000         13.0   1.000000
# max    30.000000         14.0   1.000000

# %%
frame1.describe(include=['O'])
# Out:
#         name
# count      3
# unique     3
# top     Time
# freq       1

# %%
#以0填充缺失值
frame1.fillna(0)
#丢掉任何包含NAN的行 
frame1.dropna()
#删除全为nan的行
frame1.dropna(how="all")
# Out:
#    name  Age  friends_num  Age_group
# 0  Time   20           10          1
# 1  Jack   30           12          1
# 2  Lily   12           14          0

# %%
data = pd.DataFrame(pd.read_csv('train.csv'))

# %%
data_test = pd.DataFrame(pd.read_csv('test.csv'))

# %%
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data_test = data_test[["Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"]]

# %%
print(data_test)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                                   Kelly, Mr. James    male  34.5
# 1         3                   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                          Myles, Mr. Thomas Francis    male  62.0
# 3         3                                   Wirz, Mr. Albert    male  27.0
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5         3                         Svensson, Mr. Johan Cervin    male  14.0
# 6         3                               Connolly, Miss. Kate  female  30.0
# 7         2                       Caldwell, Mr. Albert Francis    male  26.0
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 9         3                            Davies, Mr. John Samuel    male  21.0
# 10        3                                   Ilieff, Mr. Ylio    male   NaN
# ...

# %%
x = data[["Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"]]
y = data[["Survived"]]

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
x.describe(include=['O'])
# Out:
#                                 Name   Sex Ticket        Cabin Embarked
# count                            891   891    891          204      889
# unique                           891     2    681          147        3
# top     Rush, Mr. Alfred George John  male   1601  C23 C25 C27        S
# freq                               1   577      7            4      644

# %%
data_test.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.841838   14.181209    0.896760    0.981429   55.907576
# min      1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      3.000000   39.000000    1.000000    0.000000   31.500000
# max      3.000000   76.000000    8.000000    9.000000  512.329200

# %%
data_test.describe(include=['O'])
# Out:
#                         Name   Sex    Ticket            Cabin Embarked
# count                    418   418       418               91      418
# unique                   418     2       363               76        3
# top     Denbury, Mr. Herbert  male  PC 17608  B57 B59 B63 B66        S
# freq                       1   266         5                3      270

# %%
#用众数填充缺失值
data_test["Embarked"]=data_test["Embarked"].fillna('S')

# %%
data_test["Age"]=data_test["Age"].fillna(data_test["Age"].mean())

# %%
data_test = data_test.drop([ "Cabin"], axis=1)

# %%
data_test
# Out:
#      Pclass                                               Name     Sex  \
# 0         3                                   Kelly, Mr. James    male
# 1         3                   Wilkes, Mrs. James (Ellen Needs)  female
# 2         2                          Myles, Mr. Thomas Francis    male
# 3         3                                   Wirz, Mr. Albert    male
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5         3                         Svensson, Mr. Johan Cervin    male
# 6         3                               Connolly, Miss. Kate  female
# 7         2                       Caldwell, Mr. Albert Francis    male
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9         3                            Davies, Mr. John Samuel    male
# 10        3                                   Ilieff, Mr. Ylio    male
# 11        1                         Jones, Mr. Charles Cresson    male
# ...

# %%
#根据name的长度，抽象出name_len特征 
data_test["name_len"] = data_test["Name"].apply(len)

# %%
data_test
# Out:
#      Pclass                                               Name     Sex  \
# 0         3                                   Kelly, Mr. James    male
# 1         3                   Wilkes, Mrs. James (Ellen Needs)  female
# 2         2                          Myles, Mr. Thomas Francis    male
# 3         3                                   Wirz, Mr. Albert    male
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5         3                         Svensson, Mr. Johan Cervin    male
# 6         3                               Connolly, Miss. Kate  female
# 7         2                       Caldwell, Mr. Albert Francis    male
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9         3                            Davies, Mr. John Samuel    male
# 10        3                                   Ilieff, Mr. Ylio    male
# 11        1                         Jones, Mr. Charles Cresson    male
# ...

# %%
data_test["name_class"] = data_test["Name"].apply(lambda x : x.split(",")[1]).apply(lambda x :x.split()[0])

# %%
data_test
# Out:
#      Pclass                                               Name     Sex  \
# 0         3                                   Kelly, Mr. James    male
# 1         3                   Wilkes, Mrs. James (Ellen Needs)  female
# 2         2                          Myles, Mr. Thomas Francis    male
# 3         3                                   Wirz, Mr. Albert    male
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5         3                         Svensson, Mr. Johan Cervin    male
# 6         3                               Connolly, Miss. Kate  female
# 7         2                       Caldwell, Mr. Albert Francis    male
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9         3                            Davies, Mr. John Samuel    male
# 10        3                                   Ilieff, Mr. Ylio    male
# 11        1                         Jones, Mr. Charles Cresson    male
# ...

# %%
data_test["family_num"] = data_test["Parch"] + data_test["SibSp"] +1

# %%
data_test["Embarked"]=data_test["Embarked"].map({'S':1,'C':2,'Q':3}).astype(int)

# %%
data_test["Sex"] = data_test["Sex"].apply(lambda x : 0 if x=='male' else 1)

# %%
data_test["Fare"] = data_test["Fare"].apply(lambda x:cut([7.91,14.45,31.0],x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-6635f632392e> in <module>()
# ----> 1 data_test["Fare"] = data_test["Fare"].apply(lambda x:cut([7.91,14.45,31.0],x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-48-6635f632392e> in <lambda>(x)
# ----> 1 data_test["Fare"] = data_test["Fare"].apply(lambda x:cut([7.91,14.45,31.0],x))
#
# NameError: name 'cut' is not defined

# %%
print(frame)
# Out:
#    name  Age  weight
# 0  Time   20    56.7
# 1  Jack   30    64.0
# 2  Lily   12    50.0

# %%
frame['weight']
# Out:
# 0    56.7
# 1    64.0
# 2    50.0
# Name: weight, dtype: float64

# %%
data_test
# Out:
#      Pclass                                               Name  Sex       Age  \
# 0         3                                   Kelly, Mr. James    0  34.50000
# 1         3                   Wilkes, Mrs. James (Ellen Needs)    1  47.00000
# 2         2                          Myles, Mr. Thomas Francis    0  62.00000
# 3         3                                   Wirz, Mr. Albert    0  27.00000
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.00000
# 5         3                         Svensson, Mr. Johan Cervin    0  14.00000
# 6         3                               Connolly, Miss. Kate    1  30.00000
# 7         2                       Caldwell, Mr. Albert Francis    0  26.00000
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1  18.00000
# 9         3                            Davies, Mr. John Samuel    0  21.00000
# 10        3                                   Ilieff, Mr. Ylio    0  30.27259
# ...

# %%
pd.cut(frame['Age'],[0,25,35,99],labels=['0','1','2'])
# Out:
# 0    0
# 1    1
# 2    0
# Name: Age, dtype: category
# Categories (3, object): [0 < 1 < 2]

# %%
frame['Age'] = pd.cut(frame['Age'],[0,25,35,99],labels=['0','1','2'])

# %%
frame
# Out:
#    name Age weight
# 0  Time   0      1
# 1  Jack   1      2
# 2  Lily   0      1

# %%
data_test['Fare'] = pd.cut(data_test['Fare'],[0,7.91,14.45,31.0,300],labels=['0','1','2','3'])

# %%
data_test
# Out:
#      Pclass                                               Name  Sex       Age  \
# 0         3                                   Kelly, Mr. James    0  34.50000
# 1         3                   Wilkes, Mrs. James (Ellen Needs)    1  47.00000
# 2         2                          Myles, Mr. Thomas Francis    0  62.00000
# 3         3                                   Wirz, Mr. Albert    0  27.00000
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.00000
# 5         3                         Svensson, Mr. Johan Cervin    0  14.00000
# 6         3                               Connolly, Miss. Kate    1  30.00000
# 7         2                       Caldwell, Mr. Albert Francis    0  26.00000
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1  18.00000
# 9         3                            Davies, Mr. John Samuel    0  21.00000
# 10        3                                   Ilieff, Mr. Ylio    0  30.27259
# ...

# %%
data_test['Age'].max()
# Out:
# 76.0

# %%
data_test['Age'] = pd.cut(data_test['Age'],[0,18,48,64,80],labels=['0','1','2','3'])

# %%
data_test
# Out:
#      Pclass                                               Name  Sex Age  \
# 0         3                                   Kelly, Mr. James    0   1
# 1         3                   Wilkes, Mrs. James (Ellen Needs)    1   1
# 2         2                          Myles, Mr. Thomas Francis    0   2
# 3         3                                   Wirz, Mr. Albert    0   1
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1   1
# 5         3                         Svensson, Mr. Johan Cervin    0   0
# 6         3                               Connolly, Miss. Kate    1   1
# 7         2                       Caldwell, Mr. Albert Francis    0   1
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1   0
# 9         3                            Davies, Mr. John Samuel    0   1
# 10        3                                   Ilieff, Mr. Ylio    0   1
# 11        1                         Jones, Mr. Charles Cresson    0   1
# ...

# %%
rf_params = {
        'n_jobs': -1,
        'n_estimators': 500,
        'warm_start': True,
        # 'max_features': 0.2,
        'max_depth': 6,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'verbose': 0
    }

# %%
 # Extra Trees 随机森林
et_params = {
        'n_jobs': -1,
        'n_estimators': 500,
        # 'max_features': 0.5,
        'max_depth': 8,
        'min_samples_leaf': 2,
        'verbose': 0
    }

# %%
 # AdaBoost 
ada_params = {
        'n_estimators': 500,
        'learning_rate': 0.75
    }

# %%
# GBDT
gb_params = {
        'n_estimators': 500,
        # 'max_features': 0.2,
        'max_depth': 5,
        'min_samples_leaf': 2,
        'verbose': 0
    }

# %%
# SVC
svc_params = {
        'kernel': 'linear',
        'C': 0.025
    }

# %%
classifiers = [
        ("rf_model", RandomForestClassifier(**rf_params)),
        ("et_model", ExtraTreesClassifier(**et_params)),
        ("ada_model", AdaBoostClassifier(**ada_params)),
        ("gb_model", GradientBoostingClassifier(**gb_params)),
        ("svc_model", SVC(**svc_params)),
    ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-60fba9c5755a> in <module>()
#       1 classifiers = [
# ----> 2         ("rf_model", RandomForestClassifier(**rf_params)),
#       3         ("et_model", ExtraTreesClassifier(**et_params)),
#       4         ("ada_model", AdaBoostClassifier(**ada_params)),
#       5         ("gb_model", GradientBoostingClassifier(**gb_params)),
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.ensemble import SVC
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-97-1103a8019c7e> in <module>()
# ----> 1 from sklearn.ensemble import SVC
#
# ImportError: cannot import name 'SVC'

# %%
from sklearn.svm import SVC

# %%
classifiers = [
        ("rf_model", RandomForestClassifier(**rf_params)),
        ("et_model", ExtraTreesClassifier(**et_params)),
        ("ada_model", AdaBoostClassifier(**ada_params)),
        ("gb_model", GradientBoostingClassifier(**gb_params)),
        ("svc_model", SVC(**svc_params)),
    ]

# %%
heldout = [0.95, 0.90, 0.75, 0.50, 0.01]
rounds = 20

# %%
xx = 1. - np.array(heldout)

# %%
print(xx)
# Out:
# [0.05 0.1  0.25 0.5  0.99]

# %%
for name, clf in classifiers:
        print("training %s" % name)
# Out:
# training rf_model
# training et_model
# training ada_model
# training gb_model
# training svc_model

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x_train, labels_train, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-6a60c5ac4000> in <module>()
#       6             yy_ = []
#       7             for r in range(rounds):
# ----> 8                 X_train_turn, X_test_turn, y_train_turn, y_test_turn =                     train_test_split(x_train, labels_train, test_size=i, random_state=rng)
#       9                 clf.fit(X_train_turn, y_train_turn)
#      10                 y_pred = clf.predict(X_test_turn)
#
# NameError: name 'x_train' is not defined

# %%
x
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# 6         1                            McCarthy, Mr. Timothy J    male  54.0
# 7         3                     Palsson, Master. Gosta Leonard    male   2.0
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10        3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
y
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           1
# 9           1
# 10          1
# 11          1
# 12          0
# 13          0
# 14          0
# 15          1
# 16          0
# 17          1
# 18          0
# 19          1
# 20          0
# 21          1
# 22          1
# 23          1
# 24          0
# 25          1
# 26          0
# 27          0
# 28          1
# 29          0
# ..        ...
# 861         0
# 862         1
# 863         0
# 864         0
# 865         1
# 866         1
# 867         0
# 868         0
# 869         1
# 870         0
# 871         1
# 872         0
# 873         0
# 874         1
# 875         1
# 876         0
# 877         0
# 878         0
# 879         1
# 880         1
# 881         0
# 882         0
# 883         0
# 884         0
# 885         0
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# ...

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-be24556e0b93> in <module>()
#       7             for r in range(rounds):
#       8                 X_train_turn, X_test_turn, y_train_turn, y_test_turn =                     train_test_split(x, y, test_size=i, random_state=rng)
# ----> 9                 clf.fit(X_train_turn, y_train_turn)
#      10                 y_pred = clf.predict(X_test_turn)
#      11                 yy_.append(1 - np.mean(y_pred == y_test_turn))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
# ...

# %%
x["Embarked"]=x["Embarked"].fillna('S')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x["Age"]=x["Age"].fillna(x["Age"].mean())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x = x.drop([ "Cabin"], axis=1)

# %%
x["name_len"] = x["Name"].apply(len)

# %%
x["name_class"] = x["Name"].apply(lambda x : x.split(",")[1]).apply(lambda x :x.split()[0])

# %%
x["family_num"] = x["Parch"] + x["SibSp"] +1

# %%
#Embarked
x["Embarked"]=x["Embarked"].map({'S':1,'C':2,'Q':3}).astype(int)
#Sex
x["Sex"] = x["Sex"].apply(lambda x : 0 if x=='male' else 1)

# %%
x['Age'] = pd.cut(x['Age'],[0,18,48,64,90],labels=['0','1','2','3'])
x['Fare'] = pd.cut(x['Fare'],[0,7.91,14.45,31.0,600],labels=['0','1','2','3'])

# %%
x
# Out:
#      Pclass                                               Name  Sex Age  \
# 0         3                            Braund, Mr. Owen Harris    0   1
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   1
# 2         3                             Heikkinen, Miss. Laina    1   1
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   1
# 4         3                           Allen, Mr. William Henry    0   1
# 5         3                                   Moran, Mr. James    0   1
# 6         1                            McCarthy, Mr. Timothy J    0   2
# 7         3                     Palsson, Master. Gosta Leonard    0   0
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1   1
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)    1   0
# 10        3                    Sandstrom, Miss. Marguerite Rut    1   0
# 11        1                           Bonnell, Miss. Elizabeth    1   2
# ...

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-be24556e0b93> in <module>()
#       7             for r in range(rounds):
#       8                 X_train_turn, X_test_turn, y_train_turn, y_test_turn =                     train_test_split(x, y, test_size=i, random_state=rng)
# ----> 9                 clf.fit(X_train_turn, y_train_turn)
#      10                 y_pred = clf.predict(X_test_turn)
#      11                 yy_.append(1 - np.mean(y_pred == y_test_turn))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
# ...

# %%
x
# Out:
#      Pclass                                               Name  Sex Age  \
# 0         3                            Braund, Mr. Owen Harris    0   1
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   1
# 2         3                             Heikkinen, Miss. Laina    1   1
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   1
# 4         3                           Allen, Mr. William Henry    0   1
# 5         3                                   Moran, Mr. James    0   1
# 6         1                            McCarthy, Mr. Timothy J    0   2
# 7         3                     Palsson, Master. Gosta Leonard    0   0
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1   1
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)    1   0
# 10        3                    Sandstrom, Miss. Marguerite Rut    1   0
# 11        1                           Bonnell, Miss. Elizabeth    1   2
# ...

# %%
x = x[["Pclass","name_len","Sex","Age","SibSp","Parch","Fare","Embarked","family_num"]]

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-be24556e0b93> in <module>()
#       7             for r in range(rounds):
#       8                 X_train_turn, X_test_turn, y_train_turn, y_test_turn =                     train_test_split(x, y, test_size=i, random_state=rng)
# ----> 9                 clf.fit(X_train_turn, y_train_turn)
#      10                 y_pred = clf.predict(X_test_turn)
#      11                 yy_.append(1 - np.mean(y_pred == y_test_turn))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
# ...

# %%
x
# Out:
#      Pclass  name_len  Sex Age  SibSp  Parch Fare  Embarked  family_num
# 0         3        23    0   1      1      0    0         1           2
# 1         1        51    1   1      1      0    3         2           2
# 2         3        22    1   1      0      0    1         1           1
# 3         1        44    1   1      1      0    3         1           2
# 4         3        24    0   1      0      0    1         1           1
# 5         3        16    0   1      0      0    1         3           1
# 6         1        23    0   2      0      0    3         1           1
# 7         3        30    0   0      3      1    2         1           5
# 8         3        49    1   1      0      2    1         1           3
# 9         2        35    1   0      1      0    2         2           2
# 10        3        31    1   0      1      1    2         1           3
# 11        1        24    1   2      0      0    2         1           1
# ...

# %%
x.isnull().any()
# Out:
# Pclass        False
# name_len      False
# Sex           False
# Age           False
# SibSp         False
# Parch         False
# Fare           True
# Embarked      False
# family_num    False
# dtype: bool

# %%
x["Fare"]=x["Fare"].fillna('1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x.isnull().any()
# Out:
# Pclass        False
# name_len      False
# Sex           False
# Age           False
# SibSp         False
# Parch         False
# Fare          False
# Embarked      False
# family_num    False
# dtype: bool

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-be24556e0b93> in <module>()
#       9                 clf.fit(X_train_turn, y_train_turn)
#      10                 y_pred = clf.predict(X_test_turn)
# ---> 11                 yy_.append(1 - np.mean(y_pred == y_test_turn))
#      12             yy.append(np.mean(yy_))
#      13         plt.plot(xx, yy, label=name)
#
# ...

# %%
plt.legend(loc="upper right")
plt.xlabel("Proportion train")
plt.ylabel("Test Error Rate")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
X_train_turn, X_test_turn, y_train_turn, y_test_turn = train_test_split(x, y, test_size=i, random_state=rng)

# %%
print(y_test_turn)
# Out:
#      Survived
# 384         0
# 210         0
# 486         1
# 425         0
# 855         1
# 109         1
# 790         0
# 438         0
# 481         0
# 452         0
# 134         0
# 403         0
# 42          0
# 809         1
# 726         1
# 303         1
# 239         0
# 229         0
# 803         1
# 420         0
# 120         0
# 596         1
# 496         1
# 350         0
# 658         0
# 202         0
# 588         0
# 725         0
# 111         0
# 561         0
# ..        ...
# 112         0
# 531         0
# 224         1
# 723         0
# 786         1
# 837         0
# 409         0
# 325         1
# 644         1
# 299         1
# 172         1
# 434         0
# 25          1
# 391         1
# 714         0
# 193         1
# 440         1
# 573         1
# 503         0
# 605         0
# 117         0
# 645         1
# 3           1
# 74          1
# 731         0
# 467         0
# 321         0
# 5           0
# 222         0
# 547         1
#
# ...

# %%
clf.fit(X_train_turn, y_train_turn)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:305: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0, warm_start=True)

# %%
y_pred = clf.predict(X_test_turn)

# %%
yy_.append(1 - np.mean(y_pred == y_test_turn))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-6d849b5572e6> in <module>()
# ----> 1 yy_.append(1 - np.mean(y_pred == y_test_turn))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1595             res = self._combine_const(other, func,
#    1596                                       errors='ignore',
# -> 1597                                       try_cast=False)
#    1598             return res.fillna(True).astype(bool)
#    1599
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
# ...

# %%
y_pred == y_test_turn
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-f9d1963b2efa> in <module>()
# ----> 1 y_pred == y_test_turn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1595             res = self._combine_const(other, func,
#    1596                                       errors='ignore',
# -> 1597                                       try_cast=False)
#    1598             return res.fillna(True).astype(bool)
#    1599
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    4774         new_data = self._data.eval(func=func, other=other,
# ...

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn["Survived"].values))
            yy.append(np.mean(yy_))
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:305: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# training et_model
# ...

# %%
y_pred
# Out:
# array([0, 0, 1, 1, 1, 0, 1, 0, 1], dtype=int64)

# %%
y_test_turn["Survived"].values
# Out:
# array([0, 0, 1, 1, 1, 0, 1, 0, 0], dtype=int64)

# %%
y_pred == y_test_turn["Survived"].values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True, False])

# %%
for name, clf in classifiers:
        print("training %s" % name)
        rng = np.random.RandomState(42)
        yy = []
        for i in heldout:
            yy_ = []
            for r in range(rounds):
                X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=i, random_state=rng)
                clf.fit(X_train_turn, y_train_turn)
                y_pred = clf.predict(X_test_turn)
                yy_.append(1 - np.mean(y_pred == y_test_turn["Survived"].values))
            yy.append(np.mean(yy_))
        plt.legend(loc="upper right")
        plt.plot(xx, yy, label=name)
# Out:
# training rf_model
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:305: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# No handles with labels found to put in legend.
# training et_model
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# ...

# %%
# Out:
# No handles with labels found to put in legend.

# %%
def modelScore(x_train,labels_train,x_test,y_test,model_name,et_params):
    print(("--------%s------------")%(model_name))
    model = model_name(**et_params)

    model.fit(x_train, labels_train)
    if "feature_importances_" in dir(model):
        print(model.feature_importances_)

    print (classification_report(
        labels_train,
        model.predict(x_train)))

    print (classification_report(
        y_test,
        model.predict(x_test)))
    return model

# %%
modelScore(x_train, labels_train, x_test, y_test, RandomForestClassifier, rf_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-162-0baf36a8997d> in <module>()
# ----> 1 modelScore(x_train, labels_train, x_test, y_test, RandomForestClassifier, rf_params)
#
# NameError: name 'x_train' is not defined

# %%
data_test
# Out:
#      Pclass                                               Name  Sex Age  \
# 0         3                                   Kelly, Mr. James    0   1
# 1         3                   Wilkes, Mrs. James (Ellen Needs)    1   1
# 2         2                          Myles, Mr. Thomas Francis    0   2
# 3         3                                   Wirz, Mr. Albert    0   1
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1   1
# 5         3                         Svensson, Mr. Johan Cervin    0   0
# 6         3                               Connolly, Miss. Kate    1   1
# 7         2                       Caldwell, Mr. Albert Francis    0   1
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1   0
# 9         3                            Davies, Mr. John Samuel    0   1
# 10        3                                   Ilieff, Mr. Ylio    0   1
# 11        1                         Jones, Mr. Charles Cresson    0   1
# ...

# %%
data_test.isnull().any()
# Out:
# Pclass        False
# Name          False
# Sex           False
# Age           False
# SibSp         False
# Parch         False
# Ticket        False
# Fare           True
# Embarked      False
# name_len      False
# name_class    False
# family_num    False
# dtype: bool

# %%
data_test["Fare"]=data_test["Fare"].fillna('1')

# %%
data_test = data_test[["Pclass","name_len","Sex","Age","SibSp","Parch","Fare","Embarked","family_num"]]

# %%
data_set = pd.DataFrame(pd.read_csv('test.csv'))

# %%
y_test = data_set[["Survived"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-798f5a04203d> in <module>()
# ----> 1 y_test = data_set[["Survived"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...

# %%
X_train_turn, X_test_turn, y_train_turn, y_test_turn = \
                    train_test_split(x, y, test_size=0.3, random_state=0)

# %%
modelScore(X_train_turn, y_train_turn, X_test_turn, y_test_turn, RandomForestClassifier, rf_params)
# Out:
# --------<class 'sklearn.ensemble.forest.RandomForestClassifier'>------------
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# [0.13555762 0.19546323 0.40611051 0.03858995 0.03660951 0.02597039
#  0.05591033 0.04021888 0.06556958]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-6ad6788910ce> in <module>()
# ----> 1 modelScore(X_train_turn, y_train_turn, X_test_turn, y_test_turn, RandomForestClassifier, rf_params)
#
# <ipython-input-161-d46bf4850a19> in modelScore(x_train, labels_train, x_test, y_test, model_name, et_params)
#       7         print(model.feature_importances_)
#       8
# ----> 9     print (classification_report(
#      10         labels_train,
# ...

# %%
from sklearn.metrics import classification_report

# %%
modelScore(X_train_turn, y_train_turn, X_test_turn, y_test_turn, RandomForestClassifier, rf_params)
# Out:
# --------<class 'sklearn.ensemble.forest.RandomForestClassifier'>------------
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# [0.13272691 0.19121517 0.40215564 0.0408487  0.03619809 0.02632384
#  0.05858127 0.04124906 0.07070132]
#              precision    recall  f1-score   support
#
#           0       0.87      0.93      0.90       381
#           1       0.88      0.78      0.83       242
#
# avg / total       0.87      0.87      0.87       623
#
#              precision    recall  f1-score   support
#
#           0       0.85      0.89      0.87       168
#           1       0.80      0.74      0.77       100
#
# avg / total       0.83      0.83      0.83       268
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
# ...
